# %% [markdown]
# <a href="https://colab.research.google.com/github/suddhasatwabhaumik/GenAI-Tools-Google/blob/main/test_aiplatform_lib_latest_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/googleapis/python-aiplatform.git "shapely<2.0.0" "protobuf==3.19.6"

# %%
from google.cloud import aiplatform
from vertexai.language_models._language_models import TextGenerationModel, ChatModel

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
aiplatform.init(project="sb-genai-project")
model = TextGenerationModel.from_pretrained("text-bison@001")

print(model.predict( "Say something nice",  max_output_tokens=128,  temperature=0.65))
# Out:
# I like your style.

# %%
# prompt: create requirements.txt file from current environment and save it in the home directory

import pkg_resources
# !pip freeze > requirements.txt

# %%
# !ls -larth
# Out:
# total 36K
# drwxr-xr-x 1 root root 4.0K May  8 13:37 sample_data
# drwxr-xr-x 1 root root 4.0K May  9 00:08 ..
# drwxr-xr-x 1 root root 4.0K May  9 00:14 .config
# drwxr-xr-x 1 root root 4.0K May  9 00:15 .
# -rw-r--r-- 1 root root 8.4K May  9 00:16 requirements.txt

# %%
# !cat requirements.txt
# Out:
# absl-py==1.4.0
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.6.2
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# array-record==0.2.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# attrs==23.1.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# build==0.10.0
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# certifi==2022.12.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.5
# contextlib2==0.6.0.post1
# contourpy==1.0.7
# convertdate==2.4.0
# cryptography==40.0.2
# cufflinks==0.17.3
# cvxopt==1.3.0
# cvxpy==1.3.1
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.34
# dask==2022.12.1
# ...

# %%
# prompt: print python version

import sys
print(sys.version)
# Out:
# 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
